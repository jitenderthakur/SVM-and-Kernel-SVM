# %% [markdown]
# # Implementing Both Linear and Kernel SVM

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  19598943    Male   35           134000          1
# 1  15694829  Female   32           150000          1
# 2  15735878    Male   52           150000          1
# 3  15675949  Female   33           149000          1
# 4  15701537    Male   42           149000          1

# %%
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, 4].values

# %%
sns.scatterplot(x='Age',y="EstimatedSalary",hue="Purchased",data=dataset)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state =666)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #  Fitting SVM to the Training set

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state =666)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=666,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score
cm = confusion_matrix(y_test, y_pred)
accuracy=accuracy_score(y_test,y_pred)*100
recall=recall_score(y_test,y_pred)*100

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
print("accuracy scoreb = {}, recall score= {} ".format(accuracy,recall))
# Out:
# accuracy scoreb = 85.14851485148515, recall score= 69.04761904761905

# %% [markdown]
# # applying kernel svm

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state =666)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=666,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting the Test set results
y_pred_k = classifier.predict(X_test)

# %%
#confusion matrix
cm = confusion_matrix(y_test, y_pred_k)
accuracy=accuracy_score(y_test,y_pred_k)*100
recall=recall_score(y_test,y_pred_k)*100

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
print("accuracy scoreb = {}, recall score= {} ".format(accuracy,recall))
# Out:
# accuracy scoreb = 92.07920792079209, recall score= 90.47619047619048
